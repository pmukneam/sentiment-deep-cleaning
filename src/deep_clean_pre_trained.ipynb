# %%
# Install required libraries
! pip install -q transformers accelerate sentencepiece gradio pandas nltk
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 26.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 83.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 28.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.9/287.9 kB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 10.1 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done

# %% [markdown]
# #**Model: GPT-2**

# %%
# Importing models
from transformers import GPT2Tokenizer, TFGPT2LMHeadModel, AutoTokenizer, TFAutoModelForCausalLM

# %% [markdown]
# - **gpt2**

# %%
# First time run
model = TFAutoModelForCausalLM.from_pretrained('gpt2')
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/GPT-2")
# Out:
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
# Load model
#tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
#model = TFGPT2LMHeadModel.from_pretrained()
tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = TFAutoModelForCausalLM.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/GPT-2")
model.config.pad_token_id = model.config.eos_token_id
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at /content/drive/MyDrive/Colab Notebooks/Model/GPT-2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
text_1 = "Keeps only sentimental words: 'I love and like this game'"
text_2 = "Extracting words that imply sentiment of the given review: I love and like this game'"

# Encode
encoded_input_1 = tokenizer(text_1, return_tensors='tf')
encoded_input_2 = tokenizer(text_2, return_tensors='tf')

# generate outputs and decode
output_1 = model.generate(**encoded_input_1, early_stopping=True)
decoded_1 = tokenizer.decode(output_1[0])

output_2 = model.generate(**encoded_input_2, early_stopping=True)
decoded_2 = tokenizer.decode(output_2[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:745: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:854: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
print(decoded_1)
print('')
print(decoded_2)
# Out:
# Keeps only sentimental words: 'I love and like this game'
#
# The game's creator
#
# Extracting words that imply sentiment of the given review: I love and like this game'

# %% [markdown]
# **Generate Review**

# %%
# Load libraries
import pandas as pd
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Load dataset
file_path = '/content/filtered_dataset_10.csv'
df = pd.read_csv(file_path)
df
# Out:
#                                          review_text  review_score  \
# 0  Nice little throw back for zombies especially ...             1
# 1  This game is a grandaddy its better then gta 5...             1
# 2  Found the game through a humble bundle sale, a...             1
# 3                      A truely beautiful game 11/10             1
# 4  Great Game. After coming to the computer versi...             1
# 5  Well, I've played this game countless of times...             1
# 6  Yes, this is as bad as they say. Stay away, no...            -1
# 7             Awful game. 1/10 would not play again.            -1
# 8  This... this is a game... a really really bad ...            -1
# 9  An hour in, and I realize that Ubi did not str...            -1
#
#                                 filtered_review_text
# 0  nice little throw back zombies especially sinc...
# 1                     game grandaddy better gta tell
# 2  found game humble bundle sale instantly fan st...
# 3                              truely beautiful game
# 4  great game coming computer version playing mob...
# 5  well ive played game countless times buying ga...
# 6               yes bad say stay away worth download
# 7                              awful game would play
# 8  game really really bad one honestly think coul...
# 9  hour realize ubi stray far past years less pla...

# %%
# Define Variables
prefix_1 = "Keeps only sentimental words: "
prefix_2 = "Extracting words that imply sentiment of the given review: "
max_input_length = 20

def generate_review_gpt2(review_text):
  prefix = "Keeps only sentimental words: "
  # Format input
  input = prefix + review_text
  # Encode
  encoded_input = tokenizer(input,
                            max_length=max_input_length, 
                            truncation=True, 
                            return_tensors='tf')

  # generate outputs and decode
  output = model.generate(**encoded_input, 
                          early_stopping=True,
                          max_length=25,
                          repetition_penalty = 5.2,
                          top_k = 80)
  decoded = tokenizer.batch_decode(output, skip_special_tokens=True)[0]


  return decoded

# %%
df["gpt2"] = df["review_text"].apply(generate_review_gpt2)

# %%
df
# Out:
#                                          review_text  review_score  \
# 0  Nice little throw back for zombies especially ...             1
# 1  This game is a grandaddy its better then gta 5...             1
# 2  Found the game through a humble bundle sale, a...             1
# 3                      A truely beautiful game 11/10             1
# 4  Great Game. After coming to the computer versi...             1
# 5  Well, I've played this game countless of times...             1
# 6  Yes, this is as bad as they say. Stay away, no...            -1
# 7             Awful game. 1/10 would not play again.            -1
# 8  This... this is a game... a really really bad ...            -1
# 9  An hour in, and I realize that Ubi did not str...            -1
#
#                                 filtered_review_text  \
# 0  nice little throw back zombies especially sinc...
# 1                     game grandaddy better gta tell
# 2  found game humble bundle sale instantly fan st...
# 3                              truely beautiful game
# 4  great game coming computer version playing mob...
# 5  well ive played game countless times buying ga...
# 6               yes bad say stay away worth download
# 7                              awful game would play
# 8  game really really bad one honestly think coul...
# 9  hour realize ubi stray far past years less pla...
#
#                                                 gpt2
# 0  Keeps only sentimental words: Nice little thro...
# 1  Keeps only sentimental words: This game is a g...
# 2  Keeps only sentimental words: Found the game t...
# 3  Keeps only sentimental words: A truely beautif...
# 4  Keeps only sentimental words: Great Game. Afte...
# 5  Keeps only sentimental words: Well, I've playe...
# 6  Keeps only sentimental words: Yes, this is as ...
# 7  Keeps only sentimental words: Awful game. 1/10...
# 8  Keeps only sentimental words: This... this is ...
# 9  Keeps only sentimental words: An hour in, and ...

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Deep Clean/gpt2_demo.csv', index=False)

# %% [markdown]
# - **gpt2-xl**

# %%
# First time run
model = TFAutoModelForCausalLM.from_pretrained('gpt2-xl')
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/GPT-2-xl")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/6.23G [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at gpt2-xl.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Load model
tokenizer = AutoTokenizer.from_pretrained('gpt2-xl')
model = TFAutoModelForCausalLM.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/GPT-2-xl")
model.config.pad_token_id = model.config.eos_token_id
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at /content/drive/MyDrive/Colab Notebooks/Model/GPT-2-xl.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.

# %%
text_1 = "Keeps only sentimental words: 'I love and like this game'"
text_2 = "Extracting words that imply sentiment of the given review: I love and like this game'"

# Encode
encoded_input_1 = tokenizer(text_1, return_tensors='tf')
encoded_input_2 = tokenizer(text_2, return_tensors='tf')

# generate outputs and decode
output_1 = model.generate(**encoded_input_1, early_stopping=True)
decoded_1 = tokenizer.decode(output_1[0])

output_2 = model.generate(**encoded_input_2, early_stopping=True)
decoded_2 = tokenizer.decode(output_2[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:854: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(decoded_1)
print('')
print(decoded_2)
# Out:
# Keeps only sentimental words: 'I love and like this game'
#
# "I love this
#
# Extracting words that imply sentiment of the given review: I love and like this game'

# %% [markdown]
# **Generate Review**

# %%
# Load libraries
import pandas as pd
import nltk
nltk.download('punkt')

# Load dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/filtered_dataset.csv'
df = pd.read_csv(file_path)

# Define Variables
prefix_1 = "Keeps only sentimental words: "
prefix_2 = "Extracting words that imply sentiment of the given review: "
max_input_length = 20

def generate_review_gpt2_xl(review_text):
  prefix = "Keeps only sentimental words: "
  # Format input
  input = prefix + review_text
  # Encode
  encoded_input = tokenizer(input,
                            max_length=max_input_length, 
                            truncation=True, 
                            return_tensors='tf')

  # generate outputs and decode
  output = model.generate(**encoded_input, 
                          early_stopping=True,
                          max_length=25,
                          repetition_penalty = 5.2,
                          top_k = 80)
  decoded = tokenizer.batch_decode(output, skip_special_tokens=True)[0]


  return decoded

df["gpt2-xl"] = df["review_text"].apply(generate_review_gpt2_xl)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:745: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(

# %%
df
# Out:
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text  \
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
#                                                gpt2-xl
# 0    Keeps only sentimental words: So, do you kinda...
# 1    Keeps only sentimental words: a fantastic game...
# 2    Keeps only sentimental words: It turns boys in...
# 3    Keeps only sentimental words: One of my favour...
# 4    Keeps only sentimental words: good game has fu...
# ..                                                 ...
# 995  Keeps only sentimental words: Boring. Only wor...
# 996  Keeps only sentimental words: If you are looki...
# 997  Keeps only sentimental words: Thanks for the r...
# 998  Keeps only sentimental words: Lobbies have not...
# 999  Keeps only sentimental words: The gameplay isn...
#
# [1000 rows x 4 columns]

# %%
df
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Deep Clean/gpt2-xl.csv', index=False)

# %%
# Out:
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text  \
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
#                                                gpt2-xl
# 0    Keeps only sentimental words: So, do you kinda...
# 1    Keeps only sentimental words: a fantastic game...
# 2    Keeps only sentimental words: It turns boys in...
# 3    Keeps only sentimental words: One of my favour...
# 4    Keeps only sentimental words: good game has fu...
# ..                                                 ...
# 995  Keeps only sentimental words: Boring. Only wor...
# 996  Keeps only sentimental words: If you are looki...
# 997  Keeps only sentimental words: Thanks for the r...
# 998  Keeps only sentimental words: Lobbies have not...
# 999  Keeps only sentimental words: The gameplay isn...
#
# [1000 rows x 4 columns]

# %% [markdown]
# # **Model: T5**

# %%
# Importing models
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %% [markdown]
# - **t5-base**

# %%
# First time run
model = T5ForConditionalGeneration.from_pretrained("t5-base").to("cuda")
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/t5-base")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# Load model
tokenizer = T5Tokenizer.from_pretrained("t5-base")
model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/t5-base").to("cuda")
# Out:
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
text_1 = "Keeps only sentimental words: 'I love and like this game'"
text_2 = "Extracting words that imply sentiment of the given review: I love and like this game'"

# Encode
encoded_input_1 = tokenizer(text_1, return_tensors="pt").input_ids.to("cuda")
encoded_input_2 = tokenizer(text_2, return_tensors="pt").input_ids.to("cuda")

# generate outputs and decode
output_1 = model.generate(encoded_input_1, early_stopping=True)
decoded_1 = tokenizer.decode(output_1[0], skip_special_tokens=True)

output_2 = model.generate(encoded_input_2, early_stopping=True)
decoded_2 = tokenizer.decode(output_2[0], skip_special_tokens=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
print(decoded_1)
print('')
print(decoded_2)
# Out:
# 'I love and like this game'
#
# :': I love and like this game'. Extracting words that

# %% [markdown]
# **Generate Rewview**

# %%
# Load libraries
import pandas as pd
import nltk
nltk.download('punkt')

# Load dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/filtered_dataset.csv'
df = pd.read_csv(file_path)

# Define Variables
prefix_1 = "Keeps only sentimental words: "
prefix_2 = "Extracting words that imply sentiment of the given review: "
max_input_length = 50

def generate_review_t5_base(review_text):
  prefix = "Keeps only sentimental words: "
  # Format input
  input = prefix + review_text
  # Encode
  encoded_input = tokenizer(input,
                            max_length=max_input_length, 
                            truncation=True, 
                            return_tensors='pt').input_ids.to("cuda")

  # generate outputs and decode
  output = model.generate(encoded_input, 
                          early_stopping=True,
                          max_length=64)
  decoded = tokenizer.batch_decode(output, skip_special_tokens=True)[0]

  #decoded = nltk.sent_tokenize(decoded.strip())[0]

  return decoded


df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
# [1000 rows x 3 columns]

# %%
df["t5-base-prefix-1"] = df["review_text"].apply(generate_review_t5_base)

# %%
df
# Out:
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text  \
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
#                                       t5-base-prefix-1
# 0                                                 True
# 1    words: a game that is highly addictive, just s...
# 2                                                False
# 3    :) I highly recommend playing with friends and...
# 4    only sentimental words: good game has fun man ...
# ..                                                 ...
# 995                                              False
# 996                                              False
# 997                                               True
# 998  - ''The lobby'' is a ''hacker''s paradise'' - ...
# 999  a: The gameplay isn't bad... if it wasn't for ...
#
# [1000 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Deep Clean/t5-base.csv', index=False)

# %% [markdown]
# - **t5-XL**

# %%
# First time run
model = T5ForConditionalGeneration.from_pretrained("t5-3b").to("cuda")
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/t5-3b")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/11.4G [00:00<?, ?B/s]

# %%
# Load model
tokenizer = T5Tokenizer.from_pretrained("t5-3b")
model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/t5-3b").to("cuda")
# Out:
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:163: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-3b automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
text_1 = "Keeps only sentimental words: 'I love and like this game'"
text_2 = "Keeps words that imply sentiment of the given review: I love and like this game'"

# Encode
encoded_input_1 = tokenizer(text_1, return_tensors="pt").input_ids.to("cuda")
encoded_input_2 = tokenizer(text_2, return_tensors="pt").input_ids.to("cuda")

# generate outputs and decode
output_1 = model.generate(encoded_input_1, early_stopping=True)
decoded_1 = tokenizer.decode(output_1[0], skip_special_tokens=True)

output_2 = model.generate(encoded_input_2, early_stopping=True)
decoded_2 = tokenizer.decode(output_2[0], skip_special_tokens=True)

# %%
print(decoded_1)
print('')
print(decoded_2)
# Out:
# only sentimental words: 'I love this game'. '
#
# ..s graphics and sound. I love and like this game's graphics

# %% [markdown]
# **Generate Review**

# %%
# Load libraries
import pandas as pd
import nltk
nltk.download('punkt')

# Load dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/filtered_dataset.csv'
df = pd.read_csv(file_path)

# Define Variables
prefix_1 = "Keeps only sentimental words: "
prefix_2 = "Extracting words that imply sentiment of the given review: "
max_input_length = 50

def generate_review_t5_3b(review_text):
  prefix = "Keeps only sentimental words: "
  # Format input
  input = prefix + review_text
  # Encode
  encoded_input = tokenizer(input,
                            max_length=max_input_length, 
                            truncation=True, 
                            return_tensors='pt').input_ids.to("cuda")

  # generate outputs and decode
  output = model.generate(encoded_input, 
                          early_stopping=True,
                          max_length=64)
  decoded = tokenizer.batch_decode(output, skip_special_tokens=True)[0]

  #decoded = nltk.sent_tokenize(decoded.strip())[0]

  return decoded


df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
# [1000 rows x 3 columns]

# %%
df["t5-3b-prefix-1"] = df["review_text"].apply(generate_review_t5_3b)

# %%
df
# Out:
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text  \
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
#                                         t5-3b-prefix-1
# 0    ::::::      a dungeon and you have to kill you...
# 1    :.s only sentimental words: to help you out.s ...
# 2    only sentimental words:, into boys, men into m...
# 3    ........ new features and make the game even b...
# 4    ...... a man and the girl is fun game has fun ...
# ..                                                 ...
# 995  :. a cheap one. Keeps only sentimental words: ...
# 996  't't't't't't't't physics are a joke. If you ar...
# 997  only sentimental words:: )))))))))))))))))))))...
# 998  :.'Keeps only sentimental words:  :  If your l...
# 999  .. only sentimental words:.....' feel to them....
#
# [1000 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Deep Clean/t5-3b.csv', index=False)

# %% [markdown]
# - **flan-t5-base**

# %%
# First time run
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base").to("cuda")
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/flan-t5-base")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# Load model
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/flan-t5-base").to("cuda")

# %%
text_1 = "Keeps only adjective words: 'I love and like this game'"
text_2 = "keeps only words that imply sentiment of the given review: I love and like this game'"

# Encode
encoded_input_1 = tokenizer(text_1, return_tensors="pt").input_ids.to("cuda")
encoded_input_2 = tokenizer(text_2, return_tensors="pt").input_ids.to("cuda")

# generate outputs and decode
output_1 = model.generate(encoded_input_1, early_stopping=True)
decoded_1 = tokenizer.decode(output_1[0], skip_special_tokens=True)

output_2 = model.generate(encoded_input_2, early_stopping=True)
decoded_2 = tokenizer.decode(output_2[0], skip_special_tokens=True)

# %%
print(decoded_1)
print('')
print(decoded_2)
# Out:
# love
#
# I love and like this game'

# %% [markdown]
# **Generate Review**

# %%
# Load libraries
import pandas as pd
import nltk
nltk.download('punkt')

# Load dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/filtered_dataset.csv'
df = pd.read_csv(file_path)

# Define Variables
prefix_1 = "Keeps only sentimental words: "
prefix_2 = "Extracting words that imply sentiment of the given review: "
max_input_length = 50

def generate_review_flan_t5_base(review_text):
  prefix = "Keeps only sentimental words: "
  # Format input
  input = prefix + review_text
  # Encode
  encoded_input = tokenizer(input,
                            max_length=max_input_length, 
                            truncation=True, 
                            return_tensors='pt').input_ids.to("cuda")

  # generate outputs and decode
  output = model.generate(encoded_input, 
                          early_stopping=True,
                          max_length=64)
  decoded = tokenizer.batch_decode(output, skip_special_tokens=True)[0]

  #decoded = nltk.sent_tokenize(decoded.strip())[0]

  return decoded


df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
# [1000 rows x 3 columns]

# %%
df["flan-t5-base-prefix-1"] = df["review_text"].apply(generate_review_flan_t5_base)

# %%
df
# Out:
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text  \
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
#                                  flan-t5-base-prefix-1
# 0                                         Nazi Germany
# 1    a fantastic game that is highly addictive, not...
# 2    It turns boys into men, men into men, &amp; wo...
# 3                                        a lot of fun.
# 4    frog manns are fun game over too many frog man...
# ..                                                 ...
# 995                    i don't know what to do with it
# 996                                   cars are a joke.
# 997                             Thanks for the refund.
# 998  Lobbies have nothing but hackers. If you looki...
# 999                            a little money' factor.
#
# [1000 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Deep Clean/flan-t5-base.csv', index=False)

# %% [markdown]
# - **flan-t5-xl**

# %%
# First time run
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl").to("cuda")
model.save_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/flan-t5-xl")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# Load model
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-xl")
model = T5ForConditionalGeneration.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Model/flan-t5-xl").to("cuda")
# Out:
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
print(decoded_1)
print('')
print(decoded_2)
# Out:
# sucks
#
# negative

# %%
# Load libraries
import pandas as pd
import nltk
nltk.download('punkt')

# Load dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Dataset/filtered_dataset.csv'
df = pd.read_csv(file_path)

# Define Variables
prefix_1 = "Keeps only sentimental words: "
prefix_2 = "Extracting words that imply sentiment of the given review: "
max_input_length = 50

def generate_review_flan_t5_xl(review_text):
  prefix = "Keeps only sentimental words: "
  # Format input
  input = prefix + review_text
  # Encode
  encoded_input = tokenizer(input,
                            max_length=max_input_length, 
                            truncation=True, 
                            return_tensors='pt').input_ids.to("cuda")

  # generate outputs and decode
  output = model.generate(encoded_input, 
                          early_stopping=True,
                          max_length=64)
  decoded = tokenizer.batch_decode(output, skip_special_tokens=True)[0]

  #decoded = nltk.sent_tokenize(decoded.strip())[0]

  return decoded


df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
# [1000 rows x 3 columns]

# %%
df["flan-t5-xl-prefix-1"] = df["review_text"].apply(generate_review_flan_t5_xl)

# %%
df
# Out:
#                                            review_text  review_score  \
# 0    So, do you kinda want to duel wield insane wea...             1
# 1    a fantastic game that is highly addictive, not...             1
# 2    It turns boys into men, men into men, &amp; wo...             1
# 3    One of my favourite game of all time! I highly...             1
# 4    good game has fun man and the girl is fun game...             1
# ..                                                 ...           ...
# 995  Boring. Only worth buying on sale if you want ...            -1
# 996  If you are looking for fun, DON'T BUY! The car...            -1
# 997                         Thanks for the refund. :^)            -1
# 998  Lobbies have nothing but hackers. If your look...            -1
# 999  The gameplay isn't bad... if it wasn't for the...            -1
#
#                                   filtered_review_text  \
# 0    kinda want duel wield insane weapons kill mass...
# 1    fantastic game highly addictive bosses great f...
# 2                 turns boys men men men amp women men
# 3    one favourite game time highly recommend playi...
# 4    good game fun man girl fun game many frog mann...
# ..                                                 ...
# 995        boring worth buying sale want mod something
# 996  looking fun dont buy cars handle like drunk sw...
# 997                                      thanks refund
# 998  lobbies nothing hackers looking game played ps...
# 999  gameplay isnt bad wasnt fact micotransaction f...
#
#                                    flan-t5-xl-prefix-1
# 0    Nazi Germany, and then you get to play the gam...
# 1    i'm a fan of the game and i'm a fan of the series
# 2    It turns boys into men, men into men, &amp; wo...
# 3                   a lot of new features and content.
# 4                      frog manns to apply to my fface
# ..                                                 ...
# 995                                    i don't like it
# 996  physics are so bad that you can't even get a f...
# 997                          Thanks for the refund. :)
# 998  I'm not sure if this is a good thing or not, b...
# 999  a year' thing. I'm not a fan of micro transact...
#
# [1000 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Deep Clean/flan-t5-xl.csv', index=False)
